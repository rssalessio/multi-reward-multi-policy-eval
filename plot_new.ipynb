# %%
import lzma
import pickle
import matplotlib.pyplot as plt
import numpy as np
from multireward_ope.tabular.envs.make_env import make_env
from multireward_ope.tabular.reward_set import RewardSetRewardFree
import preamble_figures
import pandas as pd
import seaborn as sns
from multireward_ope.tabular.dataclasses import Config
from multireward_ope.tabular.agents.make_agent import make_agent
from multireward_ope.tabular.agents.dataclasses import AgentParameters
from scipy.stats import bootstrap

# %%
colors = {
    'SF-NR_': 'forestgreen',
    'GVFExplorer_':'black',#'#00bfc4',#'mediumorchid',#
    'MR-NaS-PE_500_False':'#f8766d',
    'Noisy-Policy_Uniform_0.3':'royalblue',
    'Noisy-Policy_Visitation based_0.3': 'firebrick',#'#3B3B3B',
}

# %%
envs =  [('Riverswim',15),('ForkedRiverswim',8),('DoubleChain',17),('NArms',15)]
envs =  [('Riverswim',20),('ForkedRiverswim',10),('DoubleChain',21),('NArms',20)]
# envs =  [('Riverswim',30),('ForkedRiverswim',15),('DoubleChain',31),('NArms',30)]
HORIZON = 1000000

data = {}
for env, N in envs:
    results = []
    
    for agent in [
                'MR-NaS-PE_500_False',
                'SF-NR_',
                'GVFExplorer_',
                'Noisy-Policy_Uniform_0.3', 
                'Noisy-Policy_Visitation based_0.3']:

        filename = f'{HORIZON}_{env}_{N}_{agent}.lzma'
        with lzma.open(f'./data/tabular/Finite_MultiplePolicies/{filename}', 'rb') as f:
            res = pickle.load(f)
            results.append((agent, res))
        data[env] = results

# %%
colors = {
    'SF-NR_': 'forestgreen',
    'GVFExplorer_':'black',#'#00bfc4',#'mediumorchid',#
    'MR-NaS-PE_500_False':'#f8766d',
    'Noisy-Policy_Uniform_0.3':'royalblue',
    'Noisy-Policy_Visitation based_0.3': 'firebrick',#'#3B3B3B',
}
fig, ax = plt.subplots(1,4, sharey=True, figsize=(12,2.5))

name_map = {
    'SF-NR_': 'SF-NR',
    'GVFExplorer_': 'GVFExplorer',
    'MR-NaS-PE_500_False': 'MR-NaS',
    'Noisy-Policy_Uniform_0.3': 'Noisy Policy (unif.)' ,
    'Noisy-Policy_Visitation based_0.3': 'Noisy Policy (visit.)'
}

idx = 0
for env, N in envs:
    
    for agent_name, res in data[env]:
        err_rel = res['abs_results'] 
        errors = np.linalg.norm(err_rel, ord=np.inf, axis=-1).max(-1)
        xvalues = np.arange(errors.shape[1]) * 500
        res = bootstrap((errors,), np.mean, confidence_level=0.95)
        ax[idx].plot(xvalues, errors.mean(0), color=colors[agent_name], label=name_map[agent_name])
        ax[idx].fill_between(xvalues, res.confidence_interval.low, res.confidence_interval.high, color=colors[agent_name], alpha=0.2)

    ax[idx].set_yscale('log')
    ax[idx].set_title(env)
    ax[idx].set_xlabel('Time-steps')
    ax[idx].ticklabel_format(style='sci', axis='x', scilimits=(0,0))
    
    idx+=1
ax[0].set_ylabel(r'${\rm E}[\max_{\pi,r} \|\hat V_r^\pi - V_r^\pi\|_\infty]$',fontsize=18)
# ax[-1].legend(bbox_to_anchor=(1.04, 1), borderaxespad=0)

ax[0].legend(loc='upper center', bbox_to_anchor=(2.3, 1.3), borderaxespad=0, ncol=5, frameon=False)

plt.savefig(f"figures/{HORIZON}_multi_policy_multi_reward_abs_error_medium.pdf", bbox_inches='tight')

# %%
envs =  [('Riverswim',15),('ForkedRiverswim',8),('DoubleChain',17),('NArms',15)]
envs =  [('Riverswim',20),('ForkedRiverswim',10),('DoubleChain',21),('NArms',20)]
# envs =  [('Riverswim',30),('ForkedRiverswim',15),('DoubleChain',31),('NArms',30)]
HORIZON = 1000000

data2 = {}
for env, N in envs:
    results = []
    
    for agent in [
                'MR-NaS-PE_500_False',
                'SF-NR_',
                'Noisy-Policy_Uniform_0.3', 
                'Noisy-Policy_Visitation based_0.3']:

        filename = f'{HORIZON}_{env}_{N}_{agent}.lzma'
        print(f'Loading {filename}')
        with lzma.open(f'./data/tabular/RewardFree_MultiplePolicies/{filename}', 'rb') as f:
            res = pickle.load(f)
            results.append((agent, res))

        data2[env] = results
# Out:
# Loading 1000000_Riverswim_20_MR-NaS-PE_500_False.lzma
# Loading 1000000_Riverswim_20_SF-NR_.lzma
# Loading 1000000_Riverswim_20_Noisy-Policy_Uniform_0.3.lzma
# Loading 1000000_Riverswim_20_Noisy-Policy_Visitation based_0.3.lzma
# Loading 1000000_ForkedRiverswim_10_MR-NaS-PE_500_False.lzma
# Loading 1000000_ForkedRiverswim_10_SF-NR_.lzma
# Loading 1000000_ForkedRiverswim_10_Noisy-Policy_Uniform_0.3.lzma
# Loading 1000000_ForkedRiverswim_10_Noisy-Policy_Visitation based_0.3.lzma
# Loading 1000000_DoubleChain_21_MR-NaS-PE_500_False.lzma
# Loading 1000000_DoubleChain_21_SF-NR_.lzma
# Loading 1000000_DoubleChain_21_Noisy-Policy_Uniform_0.3.lzma
# Loading 1000000_DoubleChain_21_Noisy-Policy_Visitation based_0.3.lzma
# Loading 1000000_NArms_20_MR-NaS-PE_500_False.lzma
# Loading 1000000_NArms_20_SF-NR_.lzma
# Loading 1000000_NArms_20_Noisy-Policy_Uniform_0.3.lzma
# Loading 1000000_NArms_20_Noisy-Policy_Visitation based_0.3.lzma

# %%
fig, ax = plt.subplots(1,4, sharey=True, figsize=(12,2.5))

name_map = {
    'SF-NR_': 'SF-NR',
    'GVFExplorer_': 'GVFExplorer',
    'MR-NaS-PE_500_False': 'MR-NaS',
    'Noisy-Policy_Uniform_0.3': 'Noisy Policy (unif.)' ,
    'Noisy-Policy_Visitation based_0.3': 'Noisy Policy (visit.)'
}
name_map = {
    'SF-NR_': 'SF-NR',
    'GVFExplorer_': 'GVFExplorer',
    'MR-NaS-PE_500_False': 'MR-NaS',
    'Noisy-Policy_Uniform_0.3': 'Noisy Policy (unif.)' ,
    'Noisy-Policy_Visitation based_0.3': 'Noisy Policy (visit.)'
}

idx = 0
for env, N in envs:
    
    # for agent_name, res in data2[env]:
    for agent_name, res in data2[env]:
        err_rel = res['abs_results'] 
        errors = np.linalg.norm(err_rel, ord=np.inf, axis=-1).max(-1)
        xvalues = np.arange(errors.shape[1]) * 500
        res = bootstrap((errors,), np.mean, confidence_level=0.95)
        ax[idx].plot(xvalues, errors.mean(0), color=colors[agent_name], label=name_map[agent_name])
        ax[idx].fill_between(xvalues, res.confidence_interval.low, res.confidence_interval.high, color=colors[agent_name], alpha=0.2)

    ax[idx].set_yscale('log')
    ax[idx].set_title(env)
    ax[idx].set_xlabel('Time-steps')
    ax[idx].ticklabel_format(style='sci', axis='x', scilimits=(0,0))
    
    idx+=1
ax[0].set_ylabel(r'${\rm E}[\max_{\pi,r} \|\hat V_r^\pi - V_r^\pi\|_\infty]$',fontsize=18)
# ax[-1].legend(bbox_to_anchor=(1.04, 1), borderaxespad=0)

ax[0].legend(loc='upper center', bbox_to_anchor=(2.3, 1.3), borderaxespad=0, ncol=5, frameon=False)

plt.savefig(f"figures/{HORIZON}_multi_policy_rewfree_abs_error_medium.pdf", bbox_inches='tight')

# %%
envs =  [('Riverswim',15),('ForkedRiverswim',8),('DoubleChain',17),('NArms',15)]
envs =  [('Riverswim',20),('ForkedRiverswim',10),('DoubleChain',21),('NArms',20)]
envs =  [('Riverswim',30),('ForkedRiverswim',15),('DoubleChain',31),('NArms',30)]
HORIZON = 1000000

data3 = {}
for env, N in envs:
    results = []
    
    for agent in [
                'MR-NaS-PE_500_False',
                'Noisy-Policy_Uniform_0.3', 
                'Noisy-Policy_Visitation based_0.3']:

        filename = f'{HORIZON}_{env}_{N}_{agent}.lzma'
        print(f'Loading {filename}')
        with lzma.open(f'./data/tabular/RewardFree_SinglePolicy/{filename}', 'rb') as f:
            res = pickle.load(f)
            results.append((agent, res))

        data3[env] = results
# Out:
# Loading 1000000_Riverswim_30_MR-NaS-PE_500_False.lzma
# Loading 1000000_Riverswim_30_Noisy-Policy_Uniform_0.3.lzma
# Loading 1000000_Riverswim_30_Noisy-Policy_Visitation based_0.3.lzma
# Loading 1000000_ForkedRiverswim_15_MR-NaS-PE_500_False.lzma
# Loading 1000000_ForkedRiverswim_15_Noisy-Policy_Uniform_0.3.lzma
# Loading 1000000_ForkedRiverswim_15_Noisy-Policy_Visitation based_0.3.lzma
# Loading 1000000_DoubleChain_31_MR-NaS-PE_500_False.lzma
# Loading 1000000_DoubleChain_31_Noisy-Policy_Uniform_0.3.lzma
# Loading 1000000_DoubleChain_31_Noisy-Policy_Visitation based_0.3.lzma
# Loading 1000000_NArms_30_MR-NaS-PE_500_False.lzma
# Loading 1000000_NArms_30_Noisy-Policy_Uniform_0.3.lzma
# Loading 1000000_NArms_30_Noisy-Policy_Visitation based_0.3.lzma

# %%
fig, ax = plt.subplots(1,4, sharey=True, figsize=(12,2.5))

name_map = {
    'SF-NR_': 'SF-NR',
    'GVFExplorer_': 'GVFExplorer',
    'MR-NaS-PE_500_False': 'MR-NaS',
    'Noisy-Policy_Uniform_0.3': 'Noisy Policy (unif.)' ,
    'Noisy-Policy_Visitation based_0.3': 'Noisy Policy (visit.)'
}
name_map = {
    'SF-NR_': 'SF-NR',
    'GVFExplorer_': 'GVFExplorer',
    'MR-NaS-PE_500_False': 'MR-NaS',
    'Noisy-Policy_Uniform_0.3': 'Noisy Policy (unif.)' ,
    'Noisy-Policy_Visitation based_0.3': 'Noisy Policy (visit.)'
}

idx = 0
for env, N in envs:
    
    for agent_name, res in data3[env]:
        err_rel = res['abs_results'] 
        errors = np.linalg.norm(err_rel, ord=np.inf, axis=-1).max(-1)
        xvalues = np.arange(errors.shape[1]) * 500
        res = bootstrap((errors,), np.mean, confidence_level=0.95)
        ax[idx].plot(xvalues, errors.mean(0), color=colors[agent_name], label=name_map[agent_name])
        ax[idx].fill_between(xvalues, res.confidence_interval.low, res.confidence_interval.high, color=colors[agent_name], alpha=0.2)

    ax[idx].set_yscale('log')
    ax[idx].set_title(env)
    ax[idx].set_xlabel('Time-steps')
    ax[idx].ticklabel_format(style='sci', axis='x', scilimits=(0,0))
    
    idx+=1
ax[0].set_ylabel(r'${\rm E}[\max_{\pi,r} \|\hat V_r^\pi - V_r^\pi\|_\infty]$',fontsize=18)
# ax[-1].legend(bbox_to_anchor=(1.04, 1), borderaxespad=0)

ax[0].legend(loc='upper center', bbox_to_anchor=(2.3, 1.3), borderaxespad=0, ncol=5, frameon=False)

plt.savefig(f"figures/{HORIZON}_single_policy_rewfree_abs_error_large.pdf", bbox_inches='tight')

# %%
envs =  [('Riverswim',20),('ForkedRiverswim',10),('DoubleChain',21),('NArms',20)]
HORIZON = 500000
fig, ax = plt.subplots(1,4, sharey=True, figsize=(12,3.5))


idx = 0
for env, N in envs:
    results = []
    
    for agent in [
                'SF-NR_',
                'MR-NaS-PE_500_False',
                'Noisy-Policy_Uniform_0.3', 
                'Noisy-Policy_Visitation based_0.3']:

        filename = f'{HORIZON}_{env}_{N}_{agent}.lzma'
        with lzma.open(f'./data/tabular/RewardFree_MultiplePolicies/{filename}', 'rb') as f:
            res = pickle.load(f)
            results.append((agent, res))

    
    for agent_name, res in results:
        err_rel = res['abs_results'] 
        errors = np.linalg.norm(err_rel, ord=np.inf, axis=-1).max(-1)
        xvalues = np.arange(errors.shape[1])
        mu = errors.mean(0)
        ce = 1.96*errors.std(0, ddof=-1) / np.sqrt(errors.shape[0])
        ax[idx].plot(xvalues, mu, label=agent_name)
        ax[idx].fill_between(xvalues, mu-ce, mu+ce, alpha=0.2)

    ax[idx].set_yscale('log')
    ax[idx].set_title(env)
    ax[idx].set_xlabel('Epochs')
    ax[idx].set_ylabel('Absolute error')
    idx+=1
ax[-1].legend()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 18
#      16     filename = f'{HORIZON}_{env}_{N}_{agent}.lzma'
#      17     with lzma.open(f'./data/tabular/RewardFree_MultiplePolicies/{filename}', 'rb') as f:
# ---> 18         res = pickle.load(f)
#      19         results.append((agent, res))
#      22 for agent_name, res in results:
#
# File /share/pkg.8/python3/3.10.12/install/lib/python3.10/lzma.py:200, in LZMAFile.read(self, size)
#     194 """Read up to size uncompressed bytes from the file.
#     195
#     196 If size is negative or omitted, read until EOF is reached.
#     197 Returns b"" if the file is already at EOF.
#     198 """
#     199 self._check_can_read()
# --> 200 return self._buffer.read(size)
#
# File /share/pkg.8/python3/3.10.12/install/lib/python3.10/_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File /share/pkg.8/python3/3.10.12/install/lib/python3.10/_compression.py:103, in DecompressReader.read(self, size)
#     101     else:
#     102         rawblock = b""
# --> 103     data = self._decompressor.decompress(rawblock, size)
#     104 if data:
#     105     break
#
# KeyboardInterrupt:

# %%
data = {}

for env, N in [('Riverswim',30),('ForkedRiverswim',15),('DoubleChain',31),('NArms',30)]:
    data[(env, N)] ={}
    results = []
    for agent in ['Noisy-Policy_Uniform_0.3',
                'Noisy-Policy_Visitation based_0.3',
                'MR-NaS-PE_500_False']:
        
       
        

        filename = f'500000_{env}_{N}_{agent}.lzma'
        with lzma.open(f'./data/tabular/{filename}', 'rb') as f:
            res = pickle.load(f)
            data[(env,N)][agent] = res

# %%
fig, ax = plt.subplots(1,4, figsize= (12,3.5), sharey=True)
idx = 0
for env, N in [('Riverswim',30),('ForkedRiverswim',15),('DoubleChain',31),('NArms',30)]:
    
    results = []
    for agent, agent_name in [('Noisy-Policy_Uniform_0.3', r'$\epsilon$-uniform exploration'), 
                # 'Noisy-Policy_Uniform_0.15', 
                # 'Noisy-Policy_Visitation based_0.15',
                ('Noisy-Policy_Visitation based_0.3', r'$\epsilon$-visitation exploration'),
                ('MR-NaS-PE_500_False', 'MR-NaS')]:
        
       
        
        res = data[(env,N)][agent]
        values = get_values(res['cfg'])
        err_rel = res['results'] / values.max(-1,keepdims=True)[None,None,...]
        errors = np.linalg.norm(err_rel, ord=np.inf, axis=-1).max(-1)
        xvalues = np.arange(errors.shape[1]) * 250
        mu = errors.mean(0)
        ce = 1.96*errors.std(0, ddof=-1) / np.sqrt(errors.shape[0])
        ax[idx].plot(xvalues, mu, label=agent_name)
        ax[idx].fill_between(xvalues, mu-ce, mu+ce, alpha=0.2)
        ax[idx].set_title(env)
        ax[idx].set_yscale('log')
    idx += 1
ax[-1].legend()
ax[0].set_ylabel(r'$\max_{r\in {\cal R}}\|1- \frac{\hat V_r^\pi}{V_r^\pi}\|_\infty$')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
data2 = {}

for env, N in [('Riverswim',30),('ForkedRiverswim',15),('DoubleChain',31),('NArms',30)]:
    data2[(env, N)] ={}
    results = []
    for agent in ['Noisy-Policy_Uniform_0.15',
                'Noisy-Policy_Visitation based_0.15',
                'MR-NaS-PE_500_False']:
        
       
        

        filename = f'500000_{env}_{N}_{agent}.lzma'
        with lzma.open(f'./data/tabular/{filename}', 'rb') as f:
            res = pickle.load(f)
            data2[(env,N)][agent] = res

# %%
fig, ax = plt.subplots(1,4, figsize= (12,3.5), sharey=True)
idx = 0
for env, N in [('Riverswim',30),('ForkedRiverswim',15),('DoubleChain',31),('NArms',30)]:
    
    results = []
    for agent, agent_name in [('Noisy-Policy_Uniform_0.15', r'$\epsilon$-uniform exploration'), 
                # 'Noisy-Policy_Uniform_0.15', 
                # 'Noisy-Policy_Visitation based_0.15',
                ('Noisy-Policy_Visitation based_0.15', r'$\epsilon$-visitation exploration'),
                ('MR-NaS-PE_500_False', 'MR-NaS')]:
        
       
        
        res = data2[(env,N)][agent]
        values = get_values(res['cfg'])
        err_rel = res['results'] / values.max(-1,keepdims=True)[None,None,...]
        errors = np.linalg.norm(err_rel, ord=np.inf, axis=-1).max(-1)
        xvalues = np.arange(errors.shape[1])
        mu = errors.mean(0)
        ce = 1.96*errors.std(0, ddof=-1) / np.sqrt(errors.shape[0])
        ax[idx].plot(xvalues, mu, label=agent_name)
        ax[idx].fill_between(xvalues, mu-ce, mu+ce, alpha=0.2)
        ax[idx].set_title(env)
        ax[idx].set_yscale('log')
    idx += 1
ax[-1].legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fig, ax = plt.subplots(1,4, figsize= (12,3.5), sharey=True)
#       2 idx = 0
#       3 for env, N in [('Riverswim',30),('ForkedRiverswim',15),('DoubleChain',31),('NArms',30)]:
#
# NameError: name 'plt' is not defined

# %%
data3 = {}

for env, N in [('Riverswim',30),('ForkedRiverswim',15),('DoubleChain',31),('NArms',30)]:
    data3[(env, N)] ={}
    results = []
    for agent in ['Noisy-Policy_Uniform_0.05',
                'Noisy-Policy_Visitation based_0.05',
                'MR-NaS-PE_500_False']:
        
       
        

        filename = f'500000_{env}_{N}_{agent}.lzma'
        with lzma.open(f'./data/tabular/{filename}', 'rb') as f:
            res = pickle.load(f)
            data3[(env,N)][agent] = res

# %%
fig, ax = plt.subplots(1,4, figsize= (12,3.5), sharey=True)
idx = 0
for env, N in [('Riverswim',30),('ForkedRiverswim',15),('DoubleChain',31),('NArms',30)]:
    
    results = []
    for agent, agent_name in [('Noisy-Policy_Uniform_0.05', r'$\epsilon$-uniform exploration'), 
                # 'Noisy-Policy_Uniform_0.15', 
                # 'Noisy-Policy_Visitation based_0.15',
                ('Noisy-Policy_Visitation based_0.05', r'$\epsilon$-visitation exploration'),
                ('MR-NaS-PE_500_False', 'MR-NaS')]:
        
       
        
        res = data3[(env,N)][agent]
        values = get_values(res['cfg'])
        err_rel = res['results'] / values.max(-1,keepdims=True)[None,None,...]
        errors = np.linalg.norm(err_rel, ord=np.inf, axis=-1).max(-1)
        xvalues = np.arange(errors.shape[1])
        mu = errors.mean(0)
        ce = 1.96*errors.std(0, ddof=-1) / np.sqrt(errors.shape[0])
        ax[idx].plot(xvalues, mu, label=agent_name)
        ax[idx].fill_between(xvalues, mu-ce, mu+ce, alpha=0.2)
        ax[idx].set_title(env)
        ax[idx].set_yscale('log')
    idx += 1
ax[-1].legend()

# %%
for horizon in [300000]:
    for num_states in [8,10,15]:#,20,30]:
        plt.figure()
        results = []
        
        for agent in ['Noisy-Policy_Uniform_0.3', 
                      'Noisy-Policy_Visitation based_0.15',
                      #'MR-NaS-PE_500_False',
                      'MR-NaS-PE_500_False']:

            filename = f'{horizon}_ForkedRiverswim_{num_states}_{agent}.lzma'
            with lzma.open(f'./data/tabular/{filename}', 'rb') as f:
                res = pickle.load(f)
                results.append((agent, res))

        for agent_name, res in results:
            errors = np.linalg.norm(res['results'], ord=np.inf, axis=-1).max(-1)
            xvalues = np.arange(errors.shape[1])
            mu = errors.mean(0)
            ce = 1.96*errors.std(0, ddof=-1) / np.sqrt(errors.shape[0])
            plt.plot(xvalues, mu, label=agent_name + f'_{num_states}')
            plt.fill_between(xvalues, mu-ce, mu+ce, alpha=0.2)

        plt.yscale('log')
        plt.legend()
